# %%
library(tidyverse)
source("../scripts/00_R_presets.R")

# %% [markdown]
# ## Figure 2
#
# Ancestry, Variants, Genome Graph
#
# - D: Ancestry variation Graph

# %%
# D: Repetitive Element variation

# %%
180mm
