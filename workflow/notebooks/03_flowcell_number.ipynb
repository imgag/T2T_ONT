# %% [markdown]
# # PLot QC improvement with added FC

# %%
library(tidyverse)
library(ggplot2)
# Out:
# Warning message:
# “package ‘lubridate’ was built under R version 4.4.2”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
qc_asm <- read_tsv("../../assembly/qc/qc_flowcells.tsv")
head(qc_asm)
# Out:
# Rows: 318 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (5): metric, haplotype, asm_method, asm_name, source
# dbl (1): value
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   metric                                                    value
# 1 Number of mapped sequences                                     19122
# 2 Number of primary alignments                                   45269
# 3 Number of secondary alignments                                 34659
# 4 Number of primary alignments with >65535 CIGAR operations          0
# 5 Number of bases in mapped sequences                       6685275250
# 6 Number of mapped bases                                    6642871159
#   haplotype asm_method      asm_name    source
# 1 NA        unphased_verkko TUE_02_01UL stat
# 2 NA        unphased_verkko TUE_02_01UL stat
# 3 NA        unphased_verkko TUE_02_01UL stat
# 4 NA        unphased_verkko TUE_02_01UL stat
# 5 NA        unphased_verkko TUE_02_01UL stat
# 6 NA        unphased_verkko TUE_02_01UL stat

# %%
source("../scripts/03_plot_mapping_stats.R")
# Out:
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file '../scripts/03_plot_mapping_stats.R': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. file(filename, "r", encoding = encoding)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "cannot open the connection", base::quote(file(filename, "r",
#  .     encoding = encoding)))
